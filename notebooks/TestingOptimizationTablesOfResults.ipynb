# %% [markdown]
# # Simulations - 1

# %%
library(repr)
options(repr.plot.width=11, repr.plot.height=7, repr.plot.res = 80, repr.plot.quality = 30)
options(jupyter.plot_mimetypes = 'image/png')

setwd("~/yandexDisk/DIPLOMA/CODE/src")
source("simulations.functions.R", echo=FALSE)
debug.file <- ".various.Rdata/Iter.info"

# %%
# Defining control execution constants 
train.data.sample.sizes <- c(50, 100, 200, 400, 800)
test.data.sample.size <- 10000
number.of.covariates = 30
sample.size <- 800
offsets = seq(0.2, 1, length = 10)
control.offset = min(offsets) / 2
lambdas = seq(0,  10,  length=12)

registerDoParallel(cores = 4)
number.of.iters <- 10

offset = 0.1
lambda = 1

# %%
GetInitPars <- function(train, q=0.6) {
    index = train$reward > quantile(train$reward, q) 
    rqmodel = rq(train$treatment[index] ~ train$covariates[index,] - 1, tau=.5, 
             method="lasso", weights=train$reward[index], lambda = lambda)
    return(coef(rqmodel))
}

# %%
global.stat <- list()
for (i in seq(1,number.of.iters)) {
    train <- GetSimulationData(sample.size, number.of.covariates)
    test <- GetSimulationData(test.data.sample.size, number.of.covariates)
    init.pars = GetInitPars(train)

    opt.params = list("opt.func"=DCOptimizeWithMML2Penalized, "approximation.eps"=1e-5, "tolerance"=1e-7, "init.pars"=init.pars)
    pars.dca.MM.approx <- OptimizeParamsOfPolicyFunction(train, offset, PolicyFunLinearKernel, lambda=lambda, opt.hyperparams=opt.params)
    opt.params = list("opt.func"=DCOptimizeWithMML2Penalized, "tolerance"=1e-7, "init.pars"=init.pars)
    pars.dca.MM <- OptimizeParamsOfPolicyFunction(train, offset, PolicyFunLinearKernel, lambda=lambda, opt.hyperparams=opt.params)
    opt.params = list("opt.func"=DCOptimizeWithMML2PenalizedProperIters, "tolerance"=1e-7, "init.pars"=init.pars)
    pars.dca.true.MM <- OptimizeParamsOfPolicyFunction(train, offset, PolicyFunLinearKernel, lambda=lambda, opt.hyperparams=opt.params)
    pars.dca.l1 <- OptimizeParamsOfPolicyFunction(train, offset, PolicyFunLinearKernel, lambda, opt.hyperparams=list("opt.func"=DCOptimizeL1Penalized, "init.pars"=init.pars))
    pars.gen.sa <- OptimizeParamsOfPolicyFunction(train, offset, PolicyFunLinearKernel, lambda, opt.hyperparams=list("obj.func"=ObjectiveFunction, "init.pars"=init.pars))    
    pars.owl <- GetOwlParams(train, lambda)

    
    opt.decision <- c(1, 0.5, 0.5 , rep(0, length(pars.dca.MM) - 3))
    data.list <- list("train"=train, "test"=test)
    params.list  <- list("MM"=pars.dca.MM, "MM.appr"=pars.dca.MM.approx, "MM.proper.iters"=pars.dca.true.MM, 
                         "Lasso"=pars.dca.l1, 
                         "SimAnn"=pars.gen.sa, 
                         "Ideal"=opt.decision, "OWL"=pars.owl) 
    iter.stat <- GetMetricsForParams(params.list, data.list, offset, PolicyFunLinearKernel, lambda)
    global.stat  <- rbind(global.stat, iter.stat)
}
# Out:
# MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  2  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -23.24977049
# It: 330, obj value: -25.15932392
# It: 882, obj value: -25.32094046
# It: 1, obj value: -25.32315132
# .............It: 1, obj value: -25.3235031
# ..........
# It: 311, obj value: -25.56899899
# .
# It: 342, obj value: -25.88395426
# .
# It: 373, obj value: -25.90110603
# .
# It: 404, obj value: -25.90275264
# .
# It: 435, obj value: -25.90471469
# .
# It: 466, obj value: -25.90567028
# .
# It: 497, obj value: -25.90595193
# .
# It: 528, obj value: -25.90686822
# ..
# It: 590, obj value: -25.90733793
# .
# It: 621, obj value: -25.90750072
# .
# It: 652, obj value: -25.90753733
# .
# It: 683, obj value: -25.90754075
# .
# It: 714, obj value: -25.90754204
# .
# It: 745, obj value: -25.90765821
# .
# It: 776, obj value: -25.90773629
# .
# It: 807, obj value: -25.90773691
# .
# It: 838, obj value: -25.9082816
# .
# It: 869, obj value: -25.90847917
# .
# It: 900, obj value: -25.90853186
# ...............It: 1, obj value: -25.90856834
# ............................................It: 1, obj value: -25.90865575
# .............MM converged after  40  iterations
# MM converged after  31  iterations
# MM converged after  15  iterations
# MML2PenalizedProperIters Converged after  4  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -20.24439439
# It: 209, obj value: -21.20654304
# It: 380, obj value: -23.75795548
# It: 1089, obj value: -23.86605513
# It: 1103, obj value: -23.8832782
# It: 1, obj value: -23.88522237
# .............It: 1, obj value: -23.88738045
# ............................................It: 1, obj value: -23.88913772
# ............................................It: 1, obj value: -23.88934278
# .......
# It: 218, obj value: -23.97847511
# .
# It: 249, obj value: -24.10623457
# .
# It: 280, obj value: -24.11506849
# .
# It: 311, obj value: -24.11942156
# .
# It: 342, obj value: -24.12047871
# .
# It: 373, obj value: -24.1239219
# .
# It: 404, obj value: -24.13112474
# MM converged after  34  iterations
# MM converged after  12  iterations
# MM converged after  16  iterations
# MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  5  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -26.06705236
# It: 461, obj value: -28.44864295
# It: 1, obj value: -28.44977307
# It: 791, obj value: -28.94892341
# It: 961, obj value: -28.97391079
# It: 1, obj value: -28.97893714
# .............It: 1, obj value: -28.98080766
# ............................................It: 1, obj value: -28.98152981
# .............MM converged after  62  iterations
# MM converged after  54  iterations
# MM converged after  21  iterations
# MM converged after  21  iterations
# MM converged after  58  iterations
# MM converged after  32  iterations
# MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  8  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -18.13954703
# It: 265, obj value: -20.36471675
# It: 658, obj value: -20.52732966
# It: 1257, obj value: -20.5336543
# It: 1, obj value: -20.53571936
# It: 624, obj value: -21.12996739
# It: 1, obj value: -21.15239658
# .............It: 1, obj value: -21.15456322
# ............................................It: 1, obj value: -21.15571687
# ......
# It: 187, obj value: -21.60297507
# .
# It: 218, obj value: -21.612297
# .
# It: 249, obj value: -21.61452044
# .
# It: 280, obj value: -21.6154866
# .
# It: 311, obj value: -21.61895164
# .
# It: 342, obj value: -21.6191575
# .
# It: 373, obj value: -21.61950061
# .
# It: 404, obj value: -21.61978618
# MM converged after  67  iterations
# MM converged after  29  iterations
# MM converged after  11  iterations
# MM converged after  3  iterations
# MML2PenalizedProperIters Converged after  5  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -23.80527498
# ..
# It: 1032, obj value: -23.9472408
# .
# It: 1063, obj value: -23.98524574
# .
# It: 1094, obj value: -23.99324754
# .
# It: 1125, obj value: -23.99787798
# .
# It: 1156, obj value: -24.00409803
# .
# It: 1187, obj value: -24.00506292
# .
# It: 1218, obj value: -24.00605157
# .
# It: 1249, obj value: -24.00689782
# .
# It: 1280, obj value: -24.00741995
# .
# It: 1311, obj value: -24.00749504
# .
# It: 1342, obj value: -24.00768448
# .
# It: 1373, obj value: -24.00772256
# .......It: 202, obj value: -25.86258585
# .
# It: 233, obj value: -25.89413377
# .
# It: 264, obj value: -25.92319899
# .
# It: 295, obj value: -25.94096987
# .
# It: 326, obj value: -25.95404707
# .
# It: 357, obj value: -25.9546807
# .
# It: 388, obj value: -25.9565755
# .
# It: 419, obj value: -25.95774183
# .
# It: 450, obj value: -25.95808187
# .
# It: 481, obj value: -25.95812348
# .
# It: 512, obj value: -25.95880856
# .
# It: 543, obj value: -25.9594114
# .
# It: 574, obj value: -25.95950831
# .
# It: 605, obj value: -25.95960496
# .
# It: 636, obj value: -25.95965899
# .
# It: 667, obj value: -25.95966581
# .
# It: 698, obj value: -25.95968988
# .
# It: 729, obj value: -25.95969237
# .
# It: 760, obj value: -25.95969264
# .
# It: 791, obj value: -25.95969624
# .
# It: 822, obj value: -25.9597016
# .
# It: 853, obj value: -25.95970557
# .
# It: 884, obj value: -25.95970704
# .
# It: 915, obj value: -25.95973043
# .
# It: 946, obj value: -25.95974757
# .
# It: 977, obj value: -25.95975034
# .
# It: 1008, obj value: -25.95975673
# .
# It: 1039, obj value: -25.95975829
# .
# It: 1070, obj value: -25.95975837
# ..
# It: 1132, obj value: -25.9597584
# .
# It: 1163, obj value: -25.95976111
# .
# It: 1194, obj value: -25.95976154
# ..
# It: 1256, obj value: -25.95976285
# .
# It: 1287, obj value: -25.95976298
# .
# It: 1318, obj value: -25.95976429
# .
# It: 1349, obj value: -25.95976686
# .
# It: 1380, obj value: -25.95976777
# It: 1, obj value: -25.95976791
# ........
# It: 249, obj value: -26.15590725
# .
# It: 280, obj value: -26.6059216
# .
# It: 311, obj value: -26.97347422
# .
# It: 342, obj value: -27.02207262
# .
# It: 373, obj value: -27.02292705
# .
# It: 404, obj value: -27.02327194
# .
# It: 435, obj value: -27.02414529
# .
# It: 466, obj value: -27.02445
# .
# It: 497, obj value: -27.02448739
# .
# It: 528, obj value: -27.02478018
# .
# It: 559, obj value: -27.02493556
# .
# It: 590, obj value: -27.02494231
# .
# It: 621, obj value: -27.02495095
# .
# It: 652, obj value: -27.02495215
# .
# It: 683, obj value: -27.02495241
# .
# It: 714, obj value: -27.02495247
# .
# It: 745, obj value: -27.02495266
# .
# It: 776, obj value: -27.02495285
# .
# It: 807, obj value: -27.02495304
# .
# It: 838, obj value: -27.0249533
# ..
# It: 900, obj value: -27.02495337
# .
# It: 931, obj value: -27.02495349
# .
# It: 962, obj value: -27.02495357
# .
# It: 993, obj value: -27.02495381
# .
# It: 1024, obj value: -27.02495395
# .
# It: 1055, obj value: -27.02495778
# .
# It: 1086, obj value: -27.02496112
# .
# It: 1117, obj value: -27.02496241
# .
# It: 1148, obj value: -27.02507327
# .
# It: 1179, obj value: -27.02556314
# .
# It: 1210, obj value: -27.02578803
# .
# It: 1241, obj value: -27.02579008
# .....
# It: 1, obj value: -27.02579023
# ............................................It: 1, obj value: -27.02579023
# .............MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  2  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -24.70288189
# It: 388, obj value: -26.65727173
# It: 685, obj value: -26.9468944
# It: 1286, obj value: -26.95237912
# It: 1350, obj value: -26.95887008
# It: 1, obj value: -26.96496661
# It: 794, obj value: -27.17954541
# It: 1, obj value: -27.18172861
# .............It: 1, obj value: -27.18202982
# ........
# It: 249, obj value: -27.36545812
# .
# It: 280, obj value: -27.80533218
# .
# It: 311, obj value: -27.80939396
# .
# It: 342, obj value: -27.81136283
# .
# It: 373, obj value: -27.81226249
# .
# It: 404, obj value: -27.81298046
# .
# It: 435, obj value: -27.81305991
# .
# It: 466, obj value: -27.81306542
# .
# It: 497, obj value: -27.81311264
# .
# It: 528, obj value: -27.81313917
# ..
# It: 590, obj value: -27.81516433
# .
# It: 621, obj value: -27.81715029
# .
# It: 652, obj value: -27.81754528
# .
# It: 683, obj value: -27.81804751
# .
# It: 714, obj value: -27.81839605
# .
# It: 745, obj value: -27.81846559
# .
# It: 776, obj value: -27.81852077
# .
# It: 807, obj value: -27.81852737
# .
# It: 838, obj value: -27.81853449
# .
# It: 869, obj value: -27.81853477
# .
# It: 900, obj value: -27.81853552
# .
# It: 931, obj value: -27.81853596
# .
# It: 962, obj value: -27.81853629
# ..
# It: 1024, obj value: -27.81853694
# .
# It: 1055, obj value: -27.81853706
# .
# It: 1086, obj value: -27.81853745
# .
# It: 1117, obj value: -27.81853748
# .
# It: 1148, obj value: -27.81853766
# .
# It: 1179, obj value: -27.81853775
# .
# It: 1210, obj value: -27.81853803
# .
# It: 1241, obj value: -27.81853908
# .
# It: 1272, obj value: -27.81853936
# .
# It: 1303, obj value: -27.8185395
# .
# It: 1334, obj value: -27.81853965
# .It: 1, obj value: -27.81853965
# .............MM converged after  41  iterations
# MM converged after  24  iterations
# MM converged after  78  iterations
# MM converged after  47  iterations
# MM converged after  61  iterations
# MM converged after  7  iterations
# MM converged after  11  iterations
# MM converged after  10  iterations
# MM converged after  28  iterations
# MM converged after  17  iterations
# MM converged after  30  iterations
# MM converged after  69  iterations
# MM converged after  13  iterations
# MM converged after  12  iterations
# MM converged after  4  iterations
# MML2PenalizedProperIters Converged after  16  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -20.9860164
# It: 519, obj value: -23.08821958
# It: 574, obj value: -23.26726113
# It: 1, obj value: -23.27288794
# .......
# It: 1187, obj value: -23.29300474
# It: 1196, obj value: -23.40225133
# .
# It: 1227, obj value: -23.40339105
# .
# It: 1258, obj value: -23.40353593
# .
# It: 1289, obj value: -23.40377019
# .
# It: 1320, obj value: -23.40409766
# .
# It: 1351, obj value: -23.40427136
# .
# It: 1382, obj value: -23.40443554
# It: 1, obj value: -23.40457197
# .....
# It: 156, obj value: -23.89828963
# .......................................It: 1, obj value: -23.89937736
# .....
# It: 156, obj value: -23.99683954
# .
# It: 187, obj value: -24.02067802
# ..
# It: 249, obj value: -24.02371823
# .
# It: 280, obj value: -24.02499961
# .
# It: 311, obj value: -24.02608974
# .
# It: 342, obj value: -24.0265431
# .
# It: 373, obj value: -24.02664502
# ..
# It: 435, obj value: -24.02673441
# .
# It: 466, obj value: -24.0275155
# .
# It: 497, obj value: -24.02788674
# .
# It: 528, obj value: -24.02795112
# .
# It: 559, obj value: -24.02795161
# .
# It: 590, obj value: -24.02795252
# .
# It: 621, obj value: -24.02837246
# .
# It: 652, obj value: -24.02880486
# .
# It: 683, obj value: -24.02908362
# .
# It: 714, obj value: -24.02926616
# .
# It: 745, obj value: -24.02929772
# .
# It: 776, obj value: -24.02929902
# ..
# It: 838, obj value: -24.02998003
# .
# It: 869, obj value: -24.02999487
# .
# It: 900, obj value: -24.03107564
# It: 930, obj value: -24.03653827
# .
# It: 961, obj value: -24.03868497
# .
# It: 992, obj value: -24.03955004
# .
# It: 1023, obj value: -24.04008683
# .
# It: 1054, obj value: -24.30682364
# .
# It: 1085, obj value: -24.36320332
# .
# It: 1116, obj value: -24.36565692
# .
# It: 1147, obj value: -24.36611832
# .
# It: 1178, obj value: -24.36673078
# .
# It: 1209, obj value: -24.36706066
# .
# It: 1240, obj value: -24.36844472
# .
# It: 1271, obj value: -24.36993781
# .
# It: 1302, obj value: -24.37007661
# .
# It: 1333, obj value: -24.37011607
# .
# It: 1364, obj value: -24.37011777
# .
# It: 1395, obj value: -24.37031432
# It: 1, obj value: -24.37039865
# .............MM converged after  89  iterations
# MM converged after  43  iterations
# MM converged after  47  iterations
# MM converged after  15  iterations
# MM converged after  32  iterations
# MM converged after  24  iterations
# MM converged after  40  iterations
# MM converged after  13  iterations
# MML2PenalizedProperIters Converged after  9  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -23.37422495
# It: 310, obj value: -26.11223266
# ...It: 1, obj value: -26.15803492
# ............................................It: 1, obj value: -26.17929612
# ...........
# It: 342, obj value: -26.2193691
# .
# It: 373, obj value: -26.22083662
# .
# It: 404, obj value: -26.22383314
# .
# It: 435, obj value: -26.22441391
# .
# It: 466, obj value: -26.22469649
# .
# It: 497, obj value: -26.22546601
# .
# It: 528, obj value: -26.22569729
# .
# It: 559, obj value: -26.2256991
# .
# It: 590, obj value: -26.22573153
# .
# It: 621, obj value: -26.22590543
# .
# It: 652, obj value: -26.2259546
# .
# It: 683, obj value: -26.22624098
# .
# It: 714, obj value: -26.22669567
# .
# It: 745, obj value: -26.22674333
# .
# It: 776, obj value: -26.2268271
# .
# It: 807, obj value: -26.22718044
# It: 809, obj value: -26.22890825
# .
# It: 840, obj value: -26.22900782
# .
# It: 871, obj value: -26.22902124
# .
# It: 902, obj value: -26.22906196
# .
# It: 933, obj value: -26.22952575
# .
# It: 964, obj value: -26.22961013
# .
# It: 995, obj value: -26.22971162
# .
# It: 1026, obj value: -26.22987712
# .
# It: 1057, obj value: -26.22989097
# .
# It: 1088, obj value: -26.23001479
# .
# It: 1119, obj value: -26.23014732
# .
# It: 1150, obj value: -26.23015313
# .
# It: 1181, obj value: -26.23015504
# .
# It: 1212, obj value: -26.23015883
# .
# It: 1243, obj value: -26.23018679
# .
# It: 1274, obj value: -26.23019632
# ..
# It: 1336, obj value: -26.2301976
# .It: 1, obj value: -26.23019825
# ...................
# It: 590, obj value: -26.24748591
# .
# It: 621, obj value: -26.28583387
# .
# It: 652, obj value: -26.2881832
# .
# It: 683, obj value: -26.28909602
# .
# It: 714, obj value: -26.28935914
# .
# It: 745, obj value: -26.28956102
# .
# It: 776, obj value: -26.28957856
# .
# It: 807, obj value: -26.28974004
# .
# It: 838, obj value: -26.29013721
# .
# It: 869, obj value: -26.29029452
# .
# It: 900, obj value: -26.29029959
# .
# It: 931, obj value: -26.29030092
# .
# It: 962, obj value: -26.29058264
# .
# It: 993, obj value: -26.29076
# .
# It: 1024, obj value: -26.29076311
# .
# It: 1055, obj value: -26.29076852
# .
# It: 1086, obj value: -26.29077462
# .
# It: 1117, obj value: -26.29077465
# ..
# It: 1179, obj value: -26.29077683
# .
# It: 1210, obj value: -26.29077697
# .
# It: 1241, obj value: -26.29077737
# .
# It: 1272, obj value: -26.2907776
# .
# It: 1303, obj value: -26.29077796
# .
# It: 1334, obj value: -26.29077807
# .
# It: 1365, obj value: -26.29077834
# .
# It: 1, obj value: -26.29077839
# .............MM converged after  56  iterations
# MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  3  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -21.11094655
# It: 221, obj value: -22.8977366
# It: 356, obj value: -23.54880484
# It: 542, obj value: -24.01533119
# It: 883, obj value: -24.02776924
# It: 1282, obj value: -24.0290058
# It: 1, obj value: -24.0290905
# .............It: 1, obj value: -24.0303439
# ............................................It: 1, obj value: -24.03086445
# ............................................It: 1, obj value: -24.0309743
# .............MM converged after  60  iterations
# MM converged after  45  iterations
# MM converged after  21  iterations
# MM converged after  1  iterations
# MML2PenalizedProperIters Converged after  5  iterations
# Converged after  4  iterations
# Initializing par with random data inside bounds
# It: 1, obj value: -25.75613732
# It: 244, obj value: -26.98096677
# .
# It: 1244, obj value: -26.98753698
# .
# It: 1275, obj value: -26.99383661
# .
# It: 1306, obj value: -26.99498496
# .
# It: 1337, obj value: -26.9977483
# .
# It: 1368, obj value: -27.00782781
# It: 1, obj value: -27.01215707
# ......
# It: 187, obj value: -28.56679175
# .
# It: 218, obj value: -28.61019771
# .
# It: 249, obj value: -28.62096214
# .
# It: 280, obj value: -28.62424542
# .
# It: 311, obj value: -28.62713362
# .
# It: 342, obj value: -28.62756577
# .
# It: 373, obj value: -28.62778239
# .
# It: 404, obj value: -28.62828132
# .
# It: 435, obj value: -28.6283167
# .
# It: 466, obj value: -28.62888166
# .
# It: 497, obj value: -28.62948516
# .
# It: 528, obj value: -28.62949092
# .
# It: 559, obj value: -28.62975474
# .
# It: 590, obj value: -28.62987444
# .
# It: 621, obj value: -28.62988118
# .
# It: 652, obj value: -28.62989358
# .
# It: 683, obj value: -28.62989705
# .
# It: 714, obj value: -28.6298994
# .
# It: 745, obj value: -28.62990026
# .
# It: 776, obj value: -28.62990045
# .
# It: 807, obj value: -28.62990328
# .
# It: 838, obj value: -28.6299033
# ...
# It: 931, obj value: -28.62990389
# .
# It: 962, obj value: -28.6299092
# .
# It: 993, obj value: -28.62990942
# .
# It: 1024, obj value: -28.62991191
# .
# It: 1055, obj value: -28.62991592
# .
# It: 1086, obj value: -28.62991821
# .
# It: 1117, obj value: -28.62991855
# .
# It: 1148, obj value: -28.62991959
# .
# It: 1179, obj value: -28.62992118
# .
# It: 1210, obj value: -28.62992269
# .
# It: 1241, obj value: -28.62992414
# .
# It: 1272, obj value: -28.62992548
# .
# It: 1303, obj value: -28.62992598
# .
# It: 1334, obj value: -28.6299265
# .
# It: 1365, obj value: -28.62992653
# .
# It: 1, obj value: -28.62992656
# ............................................It: 1, obj value: -28.62992668
# ......
# It: 187, obj value: -28.68195088
# .
# It: 218, obj value: -28.68516031
# .
# It: 249, obj value: -28.68615863
# .
# It: 280, obj value: -28.68699026
# .
# It: 311, obj value: -28.68735724
# .
# It: 342, obj value: -28.68764241
# ..
# It: 404, obj value: -28.68770871
# .
# It: 435, obj value: -28.68771483
# .
# It: 466, obj value: -28.68771638
# .
# It: 497, obj value: -28.68786372
# .
# It: 528, obj value: -28.68789633
# .
# It: 559, obj value: -28.68795147
# .
# It: 590, obj value: -28.68796115
# .
# It: 621, obj value: -28.68796583
# .
# It: 652, obj value: -28.68796826
# .
# It: 683, obj value: -28.68797033
# .
# It: 714, obj value: -28.68797056
# .
# It: 745, obj value: -28.68797489
# .
# It: 776, obj value: -28.68799352
# .
# It: 807, obj value: -28.68800662
# .
# It: 838, obj value: -28.68819997
# .
# It: 869, obj value: -28.68821027
# .
# It: 900, obj value: -28.68821062
# ......
# It: 1086, obj value: -28.688211
# .
# It: 1117, obj value: -28.68821103
# ..
# It: 1179, obj value: -28.68821126
# .
# It: 1210, obj value: -28.68821145
# .
# It: 1241, obj value: -28.68821199
# .
# It: 1272, obj value: -28.68821234
# .
# It: 1303, obj value: -28.68821247
# ...
# It: 1, obj value: -28.6882125
# .............

# %%
plot(pars.dca.true.MM, col=2, type="l")
lines(pars.owl, col=3)

# %%
melt = reshape::melt
gl.stat.df <- apply(global.stat, 2, unlist)
vf.train <- melt(gl.stat.df[, grep("VF.*TRAIN", colnames(gl.stat.df))])
vf.test <- melt(gl.stat.df[, grep("VF.*TEST", colnames(gl.stat.df))])
obj.train <- melt(gl.stat.df[, grep("OBJ.*TRAIN", colnames(gl.stat.df))])
obj.test <- melt(gl.stat.df[, grep("OBJ.*TEST", colnames(gl.stat.df))])
q.train <- melt(gl.stat.df[, grep("Q.*TRAIN", colnames(gl.stat.df))])
q.test <- melt(gl.stat.df[, grep("Q.*TEST", colnames(gl.stat.df))])

# %%
ggplot(vf.train, aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))
ggplot(vf.test, aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))
ggplot(obj.train, aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))
ggplot(obj.test, aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))
ggplot(q.train , aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))
ggplot(q.test, aes(X1, value))  + geom_line(aes(colour = X2)) + theme(text = element_text(size=15))

# %%
train <- GetSimulationData(sample.size, number.of.covariates)
test <- GetSimulationData(test.data.sample.size, number.of.covariates)
data.list <- list("train"=train, "test"=test)

quants = seq(0.05, 0.99, 0.01)
stat = list()
for (q in quants) {
    pars.owl <- GetOwlParams(train, lambda, q = q)  
    s = GetMetricsForParams(list("OWL"=pars.owl), data.list, offset, PolicyFunLinearKernel, lambda)
    stat = rbind(stat, s)
}
s = data.frame(quantile=quants,  stat)

# %%
plot(quants, unlist(s[, "Qfun.OWL.TEST"]), type="l", ylim=c(1,8), col=2, xlab="", ylab="")
lines(quants, unlist(s[, "VF.OWL.TEST"]), type="l", col=3)
title("Qfunction on Test using OWL solution", xlab = "quantiles", ylab="Qfunction value")
grid()

# %%
plot(quants, unlist(s[, "OBJF.OWL.TEST"]), type="l", xlab = "quantiles", ylab="Objective func value")
title("Objective function on Test using OWL solution")
grid()

# %% [markdown]
# Видно, что Kosorok взял квантиль, который очень близко к тому, который доставляет максимум Qfuncion.

# %%
s[which.max( unlist(s[, "VF.OWL.TEST"])), ]
# Out:
#    quantile VF.OWL.TRAIN OBJF.OWL.TRAIN Qfun.OWL.TRAIN VF.OWL.TEST
# 78     0.82      6.87041      -24.44586       7.741664    3.926488
#    OBJF.OWL.TEST Qfun.OWL.TEST
# 78     -24.33505      7.627988

# %%
PlotDecsionsVersusObserved(test, PolicyFunLinearKernel, pars.owl, offset = offset, title = "Owl decision on TEST")
